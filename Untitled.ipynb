# %%
import pandas as pd
df = pd.read_excel("./dp2015-13_Dataset.xls", engine='xlrd')
pd.set_option('display.max_columns', None)
df.head(20)
# Out:
#                  City        City_Eng City_Short    NAds  Price_Median  \
# 0           Amsterdam       Amsterdam        AMS    9520   3419.972640
# 1              Athina          Athens        ATH   10782   2064.004096
# 2           Barcelona       Barcelona        BCN    5479   3140.000000
# 3             Beograd        Belgrade        BEG   12797   1416.666667
# 4              Berlin          Berlin        BER   16772   2150.338326
# 5           Bruxelles        Brussels        BRU    7879   2357.142857
# 6           Bucuresti       Bucharest        BUH   18068   1018.518519
# 7            Budapest        Budapest        BUD    1383    896.912989
# 8      Dnepropetrovsk  Dnepropetrovsk        DNK    3136    710.227273
# 9              Dublin          Dublin        DUB     576   2983.870968
# 10         Düsseldorf      Dusseldorf        DUS    1988   1979.795918
# 11       Ekaterinburg   Yekaterinburg        EKA    9868   1628.088755
# ...
